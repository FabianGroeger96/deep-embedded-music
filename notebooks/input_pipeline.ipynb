# %% [markdown]
# # Input pipeline
#
# This notebook tests / visualises the input pipeline of the project.

# %%
import audio_pipeline

# %%
INFO_FILE_PATH = "data/DCASE18-Task5-development/evaluation_setup/fold1_train.txt"
AUDIO_FILES_PATH = "data/DCASE18-Task5-development/"
SAMPLE_RATE = 16000
BATCH_SIZE = 64
PREFETCH_BATCHES = 128

pipeline = audio_pipeline.AudioPipeline(AUDIO_FILES_PATH, INFO_FILE_PATH, SAMPLE_RATE, BATCH_SIZE, PREFETCH_BATCHES)
pipeline.generate_samples_visualise(10)
# Out:
# Found 72984 audio files.
#                    sound_file  activity_label session node_id segment
# 0    audio/DevNode1_ex1_1.wav               0       1       1       1
# 1   audio/DevNode1_ex1_10.wav               0       1       1      10
# 2  audio/DevNode1_ex1_100.wav               0       1       1     100
# 3  audio/DevNode1_ex1_101.wav               0       1       1     101
# 4  audio/DevNode1_ex1_102.wav               0       1       1     102
# 0: audio file: audio/DevNode1_ex1_1.wav, label: 0, session: 1, node id: 1, segment: 1
# Selecting neighbour randomly from 9474 samples
# Selecting opposite randomly from 40836 samples
# 1: audio file: audio/DevNode1_ex1_10.wav, label: 0, session: 1, node id: 1, segment: 10
# Selecting neighbour randomly from 9474 samples
# Selecting opposite randomly from 40836 samples
# 2: audio file: audio/DevNode1_ex1_100.wav, label: 0, session: 1, node id: 1, segment: 100
# Selecting neighbour randomly from 9474 samples
# ...
